# %%
# インストール
pip install pandas

# %%
# Colaboratoryへファイルアップロード
from google.colab import files
files.upload()

## Google Driveを直接参照する方法(認証が必要)
# import google.colab.drive
# google.colab.drive.mount('gdrive')
# Out:
#      <input type="file" id="files-d4f66a12-3dfd-4092-a673-8077dfcb3c03" name="files[]" multiple disabled />
#      <output id="result-d4f66a12-3dfd-4092-a673-8077dfcb3c03">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving a.xlsx to a.xlsx
# ...

# %%
# Excelファイルの読込み
import pandas as pd
 
fname = "a.xlsx"
sname = "Sheet1"
book = pd.read_excel(fname, sheet_name=sname) #sheetnameではなく、sheet_name
print(book)

# CSVファイルの読込み
# name = "名簿.csv"
# book = pd.read_csv(fname)
# Out:
#     1   2   3   4   5
# 0   6   7   8   9  10
# 1  11  12  13  14  15
# 2  16  17  18  19  20

# %%
# テストデータ作成
import pandas as pd
import openpyxl

df1 = pd.DataFrame([[11, 21, 31], [12, 22, 32], [31, 32, 33]],
                  index=['one', 'two', 'three'], columns=['a', 'b', 'c'])
print(df1)

# Excelファイルの書出し
xlsfname1 = 'pandas_to_excel.xlsx'
sname1 = 'new_sheet_name'
df1.to_excel(xlsfname1, sheet_name= sname1)

# 検算用
df2 = pd.read_excel(xlsfname1, sheet_name=sname1)

# Colaboratoryからファイルダウンロード
from google.colab import files
files.download(xlsfname1)
# Out:
#         a   b   c
# one    11  21  31
# two    12  22  32
# three  31  32  33
